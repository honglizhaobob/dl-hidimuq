# %% [markdown]
# # Learning 1d Pure Advection in Conservative Form
#
# To verify that our PINN implementation is working well, we test the PINN on the following problem:
# $$
#     \begin{cases}
#         u_t + au_x = 0\\
#         \lim_{|x|\rightarrow\infty}u(t, x) = 0\\
#         u(0, x) = u_0(x)
#     \end{cases}
# $$ where $u_0 = \mathcal{N}(x|0, 1)$.
#
# In this case, the NN solution is assumed to have the following model (conservative advection):
# $$
#     \frac{\partial u_{\theta_1}}{\partial t} + \frac{\partial}{\partial x}\bigg(\mathcal{V}_{\theta_2}(x)u_{\theta_1}\bigg) = 0
# $$
#
# The data is generated in `constant_advection.ipynb`.
#
# In this test case, the true advection velocity is a spatially varying function.

# %% [markdown]
# * In this example, we take the analytical solution considered in: https://www.researchgate.net/publication/235711961_Analytical_Solutions_for_Advection_and_Advection-Diffusion_Equations_with_Spatially_Variable_Coefficients
#
# The subsequent paper may also be of future interest: https://www.sciencedirect.com/science/article/pii/S0307904X99000050

# %%
from PINN.AdvectionNet import *
# Testing
import matplotlib.pyplot as plt
import torch
import numpy as np
import scipy

# set random seeds
np.random.seed(10)
torch.manual_seed(10);

import numpy as np    
import matplotlib.pyplot as plt

# %% [markdown]
# The analytic solutio is given by (quasi-Gaussian profile case):
# $$
#     u(t, x) = \frac{M_0}{x\sigma\sqrt{2\pi}}\exp\bigg(
#         -\frac{[\ln (x/x_0) - u_0t]^2}{2\sigma^2}
#     \bigg)
# $$ where $M_0$ is the mass that is conserved. The above expression satisfies the conservative advection:
# $$
#     \frac{\partial u}{\partial t} + \frac{\partial}{\partial x}\bigg(
#         v(x)u
#     \bigg) = 0
# $$ where $v(x) = u_0x$. $x\in (0, \infty)$ with vanishing boundary condition.

# %%
# define computational grids
xmin, xmax = 0.05, 4.0
nx = 2000
xgrid = np.linspace(xmin, xmax, nx)
dx = xgrid[1]-xgrid[0]

dt = 0.01
tmax = 20.0
tgrid = np.arange(0, tmax, dt)
nt = len(tgrid)

# compute solution
M0 = 1.0
u0 = 0.1
sigma = 0.2
c0 = 10.0
x0 = 0.2
u_sol = np.zeros([nt, nx])
for i in range(nt):
    t = tgrid[i]
    u_sol[i, :] = ( M0/(xgrid*sigma*np.sqrt(2*np.pi)) ) * np.exp(-((np.log(xgrid / x0)-u0*t)**2/(2*(sigma**2))))

# %%
plt.figure(1);
for i in range(nt):
    if i % 400 == 0:
        plt.plot(xgrid, u_sol[i, :], "--", lw=2.0, label=r"$t = {}$".format(i*dt));
plt.plot(xgrid, u_sol[-1, :], "--", lw=2.0, label=r"$t = {}$".format(nt*dt));
plt.title("PDE solution");
plt.legend();

plt.figure(2);
plt.contourf(tgrid, xgrid, u_sol);
plt.ylabel(r"$x$"); plt.xlabel(r"$t$");
plt.title("Contour of PDE solution");

plt.figure(3);
plt.plot(xgrid, u0*xgrid, lw=5.0, label=r"Velocity $v(x)$", color="red", alpha=0.6);
plt.legend();

# %%
# save data for PINN training
scipy.io.savemat("../data/LinearOscillator/Variable_Advection_Conservative.mat", {
    "xgrid": xgrid.reshape(1, -1),
    "tgrid": tgrid.reshape(1, -1),
    "pmc": u_sol
})

# save a smaller dataset
subsample_t = 4
subsample_x = 2
xgrid_small = xgrid.reshape(1, -1)[:, 0:-1:subsample_x].squeeze(),
tgrid_small = tgrid.reshape(1, -1)[:, 0:-1:subsample_t].squeeze()
u_sol_small = u_sol[0:-1:subsample_t, 0:-1:subsample_x]
scipy.io.savemat("../data/LinearOscillator/Variable_Advection_Conservative_small.mat", {
    "xgrid": xgrid_small,
    "tgrid": tgrid_small,
    "pmc": u_sol_small
})
print("Training data size = {}\n".format(u_sol_small.shape))
# Out:
# Training data size = (500, 1000)

# %%
# PINN experiments
# subsampled spatial training data
data_path = "../data/LinearOscillator/Variable_Advection_Conservative_small.mat"
# create PINN
pinn = AdvectionNet(indim=2, outdim=1, data_path=data_path, scheduler="ExponentialLR")
# testing training
info = train(
    pinn, pinn.optimizer, pinn.scheduler, batch_size=2**8,
    epochs=200, batch_print=200, mode="all", conservative_pde=True
)
# Out:
# ------------------------------------------------------------
#
# => Data Loaded at: ../data/LinearOscillator/Variable_Advection_Conservative_small.mat
#
# ----> Total Number of observations = 498002
#
# ------------------------------------------------------------
#
# ------------------------------------------------------------------
#
# |                      Epoch 1                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000098
# Batch PDE Loss = 0.0013704415879116309
#
# Batch Data Loss = 0.4175574199267
#
# ------------------------------------------------------------------
#
# |                      Epoch 2                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000097
# Batch PDE Loss = 0.002364303737048229
#
# Batch Data Loss = 0.1919842006564762
#
# ------------------------------------------------------------------
#
# |                      Epoch 3                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000096
# Batch PDE Loss = 0.004532704690212134
#
# Batch Data Loss = 0.07711942457012506
#
# ------------------------------------------------------------------
#
# |                      Epoch 4                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000095
# Batch PDE Loss = 0.005823837534968492
#
# Batch Data Loss = 0.029887219459762575
#
# ------------------------------------------------------------------
#
# |                      Epoch 5                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000094
# Batch PDE Loss = 0.006356630272117638
#
# Batch Data Loss = 0.013759239752178817
#
# ------------------------------------------------------------------
#
# |                      Epoch 6                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000093
# Batch PDE Loss = 0.0069803159549271
#
# Batch Data Loss = 0.008294628305004784
#
# ------------------------------------------------------------------
#
# |                      Epoch 7                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000092
# Batch PDE Loss = 0.006989658643157809
#
# Batch Data Loss = 0.0060853059897649706
#
# ------------------------------------------------------------------
#
# |                      Epoch 8                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000091
# Batch PDE Loss = 0.007050783338650283
#
# Batch Data Loss = 0.005347609693978054
#
# ------------------------------------------------------------------
#
# |                      Epoch 9                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000090
# Batch PDE Loss = 0.00712726495949053
#
# Batch Data Loss = 0.005530048617427144
#
# ------------------------------------------------------------------
#
# |                      Epoch 10                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000090
# Batch PDE Loss = 0.007021306720503306
#
# Batch Data Loss = 0.004631745041499057
#
# ------------------------------------------------------------------
#
# |                      Epoch 11                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000089
# Batch PDE Loss = 0.00713579074974206
#
# Batch Data Loss = 0.00517306804961811
#
# ------------------------------------------------------------------
#
# |                      Epoch 12                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000088
# Batch PDE Loss = 0.007305353495252948
#
# Batch Data Loss = 0.0052145340958933755
#
# ------------------------------------------------------------------
#
# |                      Epoch 13                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000087
# Batch PDE Loss = 0.007251209970968525
#
# Batch Data Loss = 0.005380385482088665
#
# ------------------------------------------------------------------
#
# |                      Epoch 14                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000086
# Batch PDE Loss = 0.007300996759665607
#
# Batch Data Loss = 0.00506718281828911
#
# ------------------------------------------------------------------
#
# |                      Epoch 15                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000085
# Batch PDE Loss = 0.00737968927899805
#
# Batch Data Loss = 0.005804739258059711
#
# ------------------------------------------------------------------
#
# |                      Epoch 16                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000084
# Batch PDE Loss = 0.0072239581493706235
#
# Batch Data Loss = 0.005847998791088494
#
# ------------------------------------------------------------------
#
# |                      Epoch 17                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000083
# Batch PDE Loss = 0.007339808894422423
#
# Batch Data Loss = 0.005943082777263224
#
# ------------------------------------------------------------------
#
# |                      Epoch 18                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000083
# Batch PDE Loss = 0.0075395280145375805
#
# Batch Data Loss = 0.006147569719413241
#
# ------------------------------------------------------------------
#
# |                      Epoch 19                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000082
# Batch PDE Loss = 0.007611355093047701
#
# Batch Data Loss = 0.005663579730713062
#
# ------------------------------------------------------------------
#
# |                      Epoch 20                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000081
# Batch PDE Loss = 0.0075897155106382
#
# Batch Data Loss = 0.00509045603962797
#
# ------------------------------------------------------------------
#
# |                      Epoch 21                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000080
# Batch PDE Loss = 0.007548850667333198
#
# Batch Data Loss = 0.004875701236178244
#
# ------------------------------------------------------------------
#
# |                      Epoch 22                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000079
# Batch PDE Loss = 0.007807817060529213
#
# Batch Data Loss = 0.0051247391074444905
#
# ------------------------------------------------------------------
#
# |                      Epoch 23                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000079
# Batch PDE Loss = 0.007742976580182738
#
# Batch Data Loss = 0.005044240355939446
#
# ------------------------------------------------------------------
#
# |                      Epoch 24                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000078
# Batch PDE Loss = 0.007419158407465321
#
# Batch Data Loss = 0.004588263757214704
#
# ------------------------------------------------------------------
#
# |                      Epoch 25                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000077
# Batch PDE Loss = 0.007087233795681532
#
# Batch Data Loss = 0.004806205414197542
#
# ------------------------------------------------------------------
#
# |                      Epoch 26                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000076
# Batch PDE Loss = 0.00690245472683203
#
# Batch Data Loss = 0.004168982434272241
#
# ------------------------------------------------------------------
#
# |                      Epoch 27                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000075
# Batch PDE Loss = 0.0070837496561922675
#
# Batch Data Loss = 0.004257893132395047
#
# ------------------------------------------------------------------
#
# |                      Epoch 28                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000075
# Batch PDE Loss = 0.007229578564330006
#
# Batch Data Loss = 0.004051888368342965
#
# ------------------------------------------------------------------
#
# |                      Epoch 29                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000074
# Batch PDE Loss = 0.007220472944457639
#
# Batch Data Loss = 0.0036952616672668677
#
# ------------------------------------------------------------------
#
# |                      Epoch 30                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000073
# Batch PDE Loss = 0.007079709685649103
#
# Batch Data Loss = 0.0039025574987691432
#
# ------------------------------------------------------------------
#
# |                      Epoch 31                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000072
# Batch PDE Loss = 0.0070738817135795945
#
# Batch Data Loss = 0.003727157440383234
#
# ------------------------------------------------------------------
#
# |                      Epoch 32                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000072
# Batch PDE Loss = 0.007095007961099302
#
# Batch Data Loss = 0.003679531215626626
#
# ------------------------------------------------------------------
#
# |                      Epoch 33                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000071
# Batch PDE Loss = 0.007006537378843208
#
# Batch Data Loss = 0.0035705913090256455
#
# ------------------------------------------------------------------
#
# |                      Epoch 34                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000070
# Batch PDE Loss = 0.006841839584977462
#
# Batch Data Loss = 0.0033169350291696402
#
# ------------------------------------------------------------------
#
# |                      Epoch 35                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000070
# Batch PDE Loss = 0.006820636742702062
#
# Batch Data Loss = 0.0034432644850870275
#
# ------------------------------------------------------------------
#
# |                      Epoch 36                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000069
# Batch PDE Loss = 0.006746826213188403
#
# Batch Data Loss = 0.003232611718623256
#
# ------------------------------------------------------------------
#
# |                      Epoch 37                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000068
# Batch PDE Loss = 0.006685274983189181
#
# Batch Data Loss = 0.0033348156922287753
#
# ------------------------------------------------------------------
#
# |                      Epoch 38                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000068
# Batch PDE Loss = 0.006679213612722329
#
# Batch Data Loss = 0.0031360887211253794
#
# ------------------------------------------------------------------
#
# |                      Epoch 39                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000067
# Batch PDE Loss = 0.006809928749373887
#
# Batch Data Loss = 0.003117870084139696
#
# ------------------------------------------------------------------
#
# |                      Epoch 40                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000066
# Batch PDE Loss = 0.006819334348893591
#
# Batch Data Loss = 0.0032558926242481855
#
# ------------------------------------------------------------------
#
# |                      Epoch 41                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000066
# Batch PDE Loss = 0.006744341837800335
#
# Batch Data Loss = 0.0030329037606485003
#
# ------------------------------------------------------------------
#
# |                      Epoch 42                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000065
# Batch PDE Loss = 0.006627137380953403
#
# Batch Data Loss = 0.003018301824012592
#
# ------------------------------------------------------------------
#
# |                      Epoch 43                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000064
# Batch PDE Loss = 0.0065307090060484595
#
# Batch Data Loss = 0.0029152136662705065
#
# ------------------------------------------------------------------
#
# |                      Epoch 44                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000064
# Batch PDE Loss = 0.00652107919499814
#
# Batch Data Loss = 0.0030064615177164944
#
# ------------------------------------------------------------------
#
# |                      Epoch 45                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000063
# Batch PDE Loss = 0.006472149091587373
#
# Batch Data Loss = 0.002983697088067436
#
# ------------------------------------------------------------------
#
# |                      Epoch 46                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000062
# Batch PDE Loss = 0.006411866297330293
#
# Batch Data Loss = 0.0029440008985332365
#
# ------------------------------------------------------------------
#
# |                      Epoch 47                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000062
# Batch PDE Loss = 0.006402788103638508
#
# Batch Data Loss = 0.002916727766863054
#
# ------------------------------------------------------------------
#
# |                      Epoch 48                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000061
# Batch PDE Loss = 0.006368917965044338
#
# Batch Data Loss = 0.0029160540647875303
#
# ------------------------------------------------------------------
#
# |                      Epoch 49                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000061
# Batch PDE Loss = 0.006314140383597412
#
# Batch Data Loss = 0.0029026495204724292
#
# ------------------------------------------------------------------
#
# |                      Epoch 50                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000060
# Batch PDE Loss = 0.006310985004330814
#
# Batch Data Loss = 0.0027929981627235895
#
# ------------------------------------------------------------------
#
# |                      Epoch 51                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000059
# Batch PDE Loss = 0.0063173245961356895
#
# Batch Data Loss = 0.0028588709959347994
#
# ------------------------------------------------------------------
#
# |                      Epoch 52                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000059
# Batch PDE Loss = 0.006296362183211074
#
# Batch Data Loss = 0.0028090138846523383
#
# ------------------------------------------------------------------
#
# |                      Epoch 53                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000058
# Batch PDE Loss = 0.006323515865628535
#
# Batch Data Loss = 0.0028530681543694055
#
# ------------------------------------------------------------------
#
# |                      Epoch 54                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000058
# Batch PDE Loss = 0.006317846509343507
#
# Batch Data Loss = 0.0028310990159924896
#
# ------------------------------------------------------------------
#
# |                      Epoch 55                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000057
# Batch PDE Loss = 0.006294963548247052
#
# Batch Data Loss = 0.0028458469023894366
#
# ------------------------------------------------------------------
#
# |                      Epoch 56                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000056
# Batch PDE Loss = 0.006285143457214382
#
# Batch Data Loss = 0.0028295348591680543
#
# ------------------------------------------------------------------
#
# |                      Epoch 57                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000056
# Batch PDE Loss = 0.006299484878851937
#
# Batch Data Loss = 0.0027618113400712757
#
# ------------------------------------------------------------------
#
# |                      Epoch 58                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000055
# Batch PDE Loss = 0.0062892512574748444
#
# Batch Data Loss = 0.002743274175335486
#
# ------------------------------------------------------------------
#
# |                      Epoch 59                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000055
# Batch PDE Loss = 0.006275537395725899
#
# Batch Data Loss = 0.0027280868112704707
#
# ------------------------------------------------------------------
#
# |                      Epoch 60                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |
#
# | => | Batch 1201 |
#
# | => | Batch 1401 |
#
# | => | Batch 1601 |
#
# | => | Batch 1801 |
# ----------
#
# ++ Learning rate reduced, now at = 0.000054
# Batch PDE Loss = 0.00625643709886048
#
# Batch Data Loss = 0.0025917395270329715
#
# ------------------------------------------------------------------
#
# |                      Epoch 61                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# | => | Batch 801 |
#
# | => | Batch 1001 |

# %%
# visualize losses
plt.figure(1, figsize=(16, 8));
plt.plot(np.log10(info["pde_loss"]), lw=2, color="red");
plt.title("PDE Loss vs. Epoch");

plt.figure(2, figsize=(16, 8));
plt.plot(np.log10(info["data_loss"]), lw=2, color="blue");
plt.title("Data Loss vs. Epoch");

# plt.figure(3, figsize=(16, 8));
# plt.plot(np.log10(info["reg_loss"]), lw=2, color="purple");
# plt.title("Regularity Loss vs. Epoch");
query = cartesian_data(pinn.tgrid, pinn.xgrid)

# D_pred = pinn.D_nn(query).reshape(pinn.nx, pinn.nt).T.detach().numpy()
# G_pred = pinn.G_nn(query).reshape(pinn.nx, pinn.nt).T.detach().numpy()
p_pred = pinn(query).reshape(pinn.nx, pinn.nt).T.detach().numpy()

# grids
tgrid = pinn.tgrid.detach().numpy()
xgrid = pinn.xgrid.detach().numpy()

p_exact = pinn.raw_data["pmc"]
dx = pinn.dx.item()
dt = pinn.dt.item()

# plt.figure(1);
# plt.contourf(xgrid, tgrid, G_pred);
# plt.colorbar();

# plt.figure(2);
# plt.plot(xgrid, G_pred[0:-1:10, :].T, alpha=0.4, lw=1.5);
# plt.plot(xgrid, 1.1*np.ones_like(xgrid), "--", lw=4.5, color="red", alpha=0.8, label="exact");
# plt.legend();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 3>()
#       1 # visualize losses
#       2 plt.figure(1, figsize=(16, 8));
# ----> 3 plt.plot(np.log10(info["pde_loss"]), lw=2, color="red");
#       4 plt.title("PDE Loss vs. Epoch");
#       6 plt.figure(2, figsize=(16, 8));
#
# NameError: name 'info' is not defined

# %%
inputs = cartesian_data(pinn.tgrid, pinn.xgrid)
G_pred = pinn.G_nn(inputs[:, 1][:, None]).reshape(pinn.nx, pinn.nt).T.detach().numpy()
p_pred = pinn(inputs).reshape(pinn.nx, pinn.nt).T.detach().numpy()

# %%
plt.figure(1);
plt.plot(pinn.xgrid.detach().numpy(), G_pred[0, :], color="red");
plt.plot(xgrid, u0*xgrid, lw=5.0, label=r"Velocity $v(x)$", color="blue", alpha=0.6);
plt.xlabel(r"$x$");
plt.ylabel(r"$G(x)$");

# %%
# interpolation
plt.contourf(pinn.xgrid.detach().numpy(), pinn.tgrid.detach().numpy(), p_pred);

# %%
dx = dx.item()

# %%
plt.figure(2);
# relative error in L^2 from KDE benchmark
l2_rel_err = np.sum(((p_pred-p_exact)**2)*dx, 1) / np.sum((p_exact**2)*dx, 1)
tgrid = pinn.tgrid.detach().numpy()
plt.plot(tgrid, l2_rel_err, color="red", lw=1.5);
plt.grid(True);
plt.title(r"Relative error in $L^2$");
plt.xlabel(r"$t$"); 
plt.ylabel(r"$L^2(\mathbb{R})$ error");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 3>()
#       1 plt.figure(2);
#       2 # relative error in L^2 from KDE benchmark
# ----> 3 l2_rel_err = np.sum(((p_pred-p_exact)**2)*dx, 1) / np.sum((p_exact**2)*dx, 1)
#       4 tgrid = pinn.tgrid.detach().numpy()
#       5 plt.plot(tgrid, l2_rel_err, color="red", lw=1.5);
#
# NameError: name 'p_exact' is not defined

# %%
model_path = "./PINN/models/linear_advection_conservative_epoch_200"
torch.save(pinn.state_dict(), model_path)
