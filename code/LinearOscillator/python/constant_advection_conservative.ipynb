# %% [markdown]
# # Learning 1d Pure Advection in Conservative Form
#
# To verify that our PINN implementation is working well, we test the PINN on the following problem:
# $$
#     \begin{cases}
#         u_t + au_x = 0\\
#         \lim_{|x|\rightarrow\infty}u(t, x) = 0\\
#         u(0, x) = u_0(x)
#     \end{cases}
# $$ where $u_0 = \mathcal{N}(x|0, 1)$.
#
# In this case, the NN solution is assumed to have the following model (conservative advection):
# $$
#     \frac{\partial u_{\theta_1}}{\partial t} + \frac{\partial}{\partial x}\bigg(\mathcal{V}_{\theta_2}(x)u_{\theta_1}\bigg) = 0
# $$
#
# The data is generated in `constant_advection.ipynb`.

# %%
from PINN.AdvectionNet import *
# Testing
import matplotlib.pyplot as plt
import torch
import numpy as np
import scipy

# set random seeds
np.random.seed(10)
torch.manual_seed(10);

import numpy as np    
import matplotlib.pyplot as plt

# load data
data_path = "../data/LinearOscillator/Pure_Advection_small_data.mat"
# create PINN
pinn = AdvectionNet(indim=2, outdim=1, data_path=data_path, scheduler="ExponentialLR")
# testing training
info = train(
    pinn, pinn.optimizer, pinn.scheduler, batch_size=2**10,
    epochs=200, batch_print=100, mode="all",
    conservative_pde=True
)
# Out:
# ------------------------------------------------------------
#
# => Data Loaded at: ../data/LinearOscillator/Pure_Advection_small_data.mat
#
# ----> Total Number of observations = 98802
#
# ------------------------------------------------------------
#
# ------------------------------------------------------------------
#
# |                      Epoch 1                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000980
# Batch PDE Loss = 0.00017075144074738384
#
# Batch Data Loss = 0.008118205073539915
#
# ------------------------------------------------------------------
#
# |                      Epoch 2                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000970
# Batch PDE Loss = 0.00016419773498639457
#
# Batch Data Loss = 0.0015147243224405693
#
# ------------------------------------------------------------------
#
# |                      Epoch 3                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000961
# Batch PDE Loss = 0.00011476789375564142
#
# Batch Data Loss = 0.00026683116861806334
#
# ------------------------------------------------------------------
#
# |                      Epoch 4                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000951
# Batch PDE Loss = 7.269892214472602e-05
#
# Batch Data Loss = 0.0001382992726997283
#
# ------------------------------------------------------------------
#
# |                      Epoch 5                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000941
# Batch PDE Loss = 5.428547222111843e-05
#
# Batch Data Loss = 0.00013187003100558175
#
# ------------------------------------------------------------------
#
# |                      Epoch 6                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000932
# Batch PDE Loss = 4.347603526972739e-05
#
# Batch Data Loss = 0.0001257154679619863
#
# ------------------------------------------------------------------
#
# |                      Epoch 7                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000923
# Batch PDE Loss = 3.729433991939174e-05
#
# Batch Data Loss = 0.00011842604582538295
#
# ------------------------------------------------------------------
#
# |                      Epoch 8                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000914
# Batch PDE Loss = 3.386063561649642e-05
#
# Batch Data Loss = 0.00012157117443214862
#
# ------------------------------------------------------------------
#
# |                      Epoch 9                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000904
# Batch PDE Loss = 3.209749792809564e-05
#
# Batch Data Loss = 0.0001334793565830001
#
# ------------------------------------------------------------------
#
# |                      Epoch 10                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000895
# Batch PDE Loss = 3.0118835319262716e-05
#
# Batch Data Loss = 0.0001176278676514336
#
# ------------------------------------------------------------------
#
# |                      Epoch 11                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000886
# Batch PDE Loss = 2.90299829675487e-05
#
# Batch Data Loss = 0.00012490726681185012
#
# ------------------------------------------------------------------
#
# |                      Epoch 12                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000878
# Batch PDE Loss = 2.779771255772491e-05
#
# Batch Data Loss = 0.00011860587518016659
#
# ------------------------------------------------------------------
#
# |                      Epoch 13                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000869
# Batch PDE Loss = 2.6291816514137146e-05
#
# Batch Data Loss = 0.00011789060459717081
#
# ------------------------------------------------------------------
#
# |                      Epoch 14                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000860
# Batch PDE Loss = 2.4725141305279494e-05
#
# Batch Data Loss = 0.00011611053011383857
#
# ------------------------------------------------------------------
#
# |                      Epoch 15                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000851
# Batch PDE Loss = 2.3857549510041557e-05
#
# Batch Data Loss = 0.000126046784435962
#
# ------------------------------------------------------------------
#
# |                      Epoch 16                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000843
# Batch PDE Loss = 2.186578630780776e-05
#
# Batch Data Loss = 0.00011455010268862413
#
# ------------------------------------------------------------------
#
# |                      Epoch 17                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000835
# Batch PDE Loss = 2.0677237222327043e-05
#
# Batch Data Loss = 0.00011494957847426679
#
# ------------------------------------------------------------------
#
# |                      Epoch 18                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000826
# Batch PDE Loss = 1.9758042472103684e-05
#
# Batch Data Loss = 0.00011848741150894185
#
# ------------------------------------------------------------------
#
# |                      Epoch 19                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000818
# Batch PDE Loss = 1.846426722638593e-05
#
# Batch Data Loss = 0.00011376194685302158
#
# ------------------------------------------------------------------
#
# |                      Epoch 20                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000810
# Batch PDE Loss = 1.8321284595355196e-05
#
# Batch Data Loss = 0.00011654265689373104
#
# ------------------------------------------------------------------
#
# |                      Epoch 21                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000802
# Batch PDE Loss = 1.727383386553838e-05
#
# Batch Data Loss = 0.00011334512089922438
#
# ------------------------------------------------------------------
#
# |                      Epoch 22                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000794
# Batch PDE Loss = 1.6098536013874634e-05
#
# Batch Data Loss = 0.00011337210738611278
#
# ------------------------------------------------------------------
#
# |                      Epoch 23                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
# ----------
#
# ++ Learning rate reduced, now at = 0.000786
# Batch PDE Loss = 1.5640608357262128e-05
#
# Batch Data Loss = 0.00011103983040694628
#
# ------------------------------------------------------------------
#
# |                      Epoch 24                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000778
# Batch PDE Loss = 1.5383817436039723e-05
#
# Batch Data Loss = 0.00011847003995039973
#
# ------------------------------------------------------------------
#
# |                      Epoch 25                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000770
# Batch PDE Loss = 1.4924726974962636e-05
#
# Batch Data Loss = 0.00011287579030652593
#
# ------------------------------------------------------------------
#
# |                      Epoch 26                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000762
# Batch PDE Loss = 1.4009520123977636e-05
#
# Batch Data Loss = 0.00011360552079584852
#
# ------------------------------------------------------------------
#
# |                      Epoch 27                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000755
# Batch PDE Loss = 1.4184496151304333e-05
#
# Batch Data Loss = 0.00011689140424995072
#
# ------------------------------------------------------------------
#
# |                      Epoch 28                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000747
# Batch PDE Loss = 1.3329794443724395e-05
#
# Batch Data Loss = 0.0001134591286830251
#
# ------------------------------------------------------------------
#
# |                      Epoch 29                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000740
# Batch PDE Loss = 1.2647871021768205e-05
#
# Batch Data Loss = 0.00011626547198598214
#
# ------------------------------------------------------------------
#
# |                      Epoch 30                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000732
# Batch PDE Loss = 1.2778203007339907e-05
#
# Batch Data Loss = 0.00011182181659648
#
# ------------------------------------------------------------------
#
# |                      Epoch 31                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000725
# Batch PDE Loss = 1.1493613989945901e-05
#
# Batch Data Loss = 0.00011125697305072995
#
# ------------------------------------------------------------------
#
# |                      Epoch 32                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000718
# Batch PDE Loss = 1.1463315343916226e-05
#
# Batch Data Loss = 0.0001174376356500032
#
# ------------------------------------------------------------------
#
# |                      Epoch 33                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000711
# Batch PDE Loss = 1.1250132767374948e-05
#
# Batch Data Loss = 0.00011571735950709784
#
# ------------------------------------------------------------------
#
# |                      Epoch 34                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000703
# Batch PDE Loss = 1.1151715919130026e-05
#
# Batch Data Loss = 0.000116349673713547
#
# ------------------------------------------------------------------
#
# |                      Epoch 35                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000696
# Batch PDE Loss = 1.0648459130975611e-05
#
# Batch Data Loss = 0.00011013470414060463
#
# ------------------------------------------------------------------
#
# |                      Epoch 36                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000689
# Batch PDE Loss = 9.995017788948035e-06
#
# Batch Data Loss = 0.00010972004796740565
#
# ------------------------------------------------------------------
#
# |                      Epoch 37                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000683
# Batch PDE Loss = 9.622285078050307e-06
#
# Batch Data Loss = 0.00011179878654743881
#
# ------------------------------------------------------------------
#
# |                      Epoch 38                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000676
# Batch PDE Loss = 9.686385012796723e-06
#
# Batch Data Loss = 0.00011109620946822163
#
# ------------------------------------------------------------------
#
# |                      Epoch 39                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000669
# Batch PDE Loss = 9.428346648526056e-06
#
# Batch Data Loss = 0.00011502195972361871
#
# ------------------------------------------------------------------
#
# |                      Epoch 40                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000662
# Batch PDE Loss = 9.034674817702758e-06
#
# Batch Data Loss = 0.00010837741304482078
#
# ------------------------------------------------------------------
#
# |                      Epoch 41                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000656
# Batch PDE Loss = 8.820009357748517e-06
#
# Batch Data Loss = 0.00011169690927242364
#
# ------------------------------------------------------------------
#
# |                      Epoch 42                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000649
# Batch PDE Loss = 8.560097923484338e-06
#
# Batch Data Loss = 0.00011014161043811396
#
# ------------------------------------------------------------------
#
# |                      Epoch 43                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000643
# Batch PDE Loss = 8.310776537661124e-06
#
# Batch Data Loss = 0.00011073094295547976
#
# ------------------------------------------------------------------
#
# |                      Epoch 44                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000636
# Batch PDE Loss = 7.93045064819224e-06
#
# Batch Data Loss = 0.00010763682431177534
#
# ------------------------------------------------------------------
#
# |                      Epoch 45                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000630
# Batch PDE Loss = 8.051489672017879e-06
#
# Batch Data Loss = 0.00010973285601346626
#
# ------------------------------------------------------------------
#
# |                      Epoch 46                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
# ----------
#
# ++ Learning rate reduced, now at = 0.000624
# Batch PDE Loss = 7.576724471108807e-06
#
# Batch Data Loss = 0.00011046024206586224
#
# ------------------------------------------------------------------
#
# |                      Epoch 47                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000617
# Batch PDE Loss = 7.479180676121557e-06
#
# Batch Data Loss = 0.00011126984431847053
#
# ------------------------------------------------------------------
#
# |                      Epoch 48                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000611
# Batch PDE Loss = 7.379409854979181e-06
#
# Batch Data Loss = 0.00011111033708676495
#
# ------------------------------------------------------------------
#
# |                      Epoch 49                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000605
# Batch PDE Loss = 6.9499998130874075e-06
#
# Batch Data Loss = 0.00010906104364378241
#
# ------------------------------------------------------------------
#
# |                      Epoch 50                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000599
# Batch PDE Loss = 6.956091354307775e-06
#
# Batch Data Loss = 0.00011512725944108533
#
# ------------------------------------------------------------------
#
# |                      Epoch 51                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000593
# Batch PDE Loss = 6.487885706179661e-06
#
# Batch Data Loss = 0.00010652791173449518
#
# ------------------------------------------------------------------
#
# |                      Epoch 52                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000587
# Batch PDE Loss = 6.422361612802442e-06
#
# Batch Data Loss = 0.00010853705712290426
#
# ------------------------------------------------------------------
#
# |                      Epoch 53                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000581
# Batch PDE Loss = 6.247715816202303e-06
#
# Batch Data Loss = 0.0001079194436695754
#
# ------------------------------------------------------------------
#
# |                      Epoch 54                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000575
# Batch PDE Loss = 6.165206521775104e-06
#
# Batch Data Loss = 0.00010845146392541368
#
# ------------------------------------------------------------------
#
# |                      Epoch 55                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000570
# Batch PDE Loss = 6.196149224009573e-06
#
# Batch Data Loss = 0.00011124130079311787
#
# ------------------------------------------------------------------
#
# |                      Epoch 56                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000564
# Batch PDE Loss = 6.069992546970567e-06
#
# Batch Data Loss = 0.00011126032312780094
#
# ------------------------------------------------------------------
#
# |                      Epoch 57                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000558
# Batch PDE Loss = 5.772205763803168e-06
#
# Batch Data Loss = 0.00010857708244329933
#
# ------------------------------------------------------------------
#
# |                      Epoch 58                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000553
# Batch PDE Loss = 5.590688992553903e-06
#
# Batch Data Loss = 0.00010673025135715929
#
# ------------------------------------------------------------------
#
# |                      Epoch 59                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000547
# Batch PDE Loss = 5.531415645097122e-06
#
# Batch Data Loss = 0.0001091594695561623
#
# ------------------------------------------------------------------
#
# |                      Epoch 60                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000542
# Batch PDE Loss = 5.509510482233061e-06
#
# Batch Data Loss = 0.00010667450922268995
#
# ------------------------------------------------------------------
#
# |                      Epoch 61                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000536
# Batch PDE Loss = 5.244166565489943e-06
#
# Batch Data Loss = 0.00010888406906638087
#
# ------------------------------------------------------------------
#
# |                      Epoch 62                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000531
# Batch PDE Loss = 5.1856057166611015e-06
#
# Batch Data Loss = 0.00010670608234351149
#
# ------------------------------------------------------------------
#
# |                      Epoch 63                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000526
# Batch PDE Loss = 5.137051671215669e-06
#
# Batch Data Loss = 0.00010699982687019383
#
# ------------------------------------------------------------------
#
# |                      Epoch 64                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000520
# Batch PDE Loss = 4.9847126140323864e-06
#
# Batch Data Loss = 0.00011020004374789612
#
# ------------------------------------------------------------------
#
# |                      Epoch 65                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000515
# Batch PDE Loss = 5.440794953556063e-06
#
# Batch Data Loss = 0.00011025334736131219
#
# ------------------------------------------------------------------
#
# |                      Epoch 66                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000510
# Batch PDE Loss = 5.092960750685028e-06
#
# Batch Data Loss = 0.00010864533336795492
#
# ------------------------------------------------------------------
#
# |                      Epoch 67                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000505
# Batch PDE Loss = 4.958958559076775e-06
#
# Batch Data Loss = 0.00010733286410083259
#
# ------------------------------------------------------------------
#
# |                      Epoch 68                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000500
# Batch PDE Loss = 5.05643508573232e-06
#
# Batch Data Loss = 0.00010977994656812509
#
# ------------------------------------------------------------------
#
# |                      Epoch 69                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
# ----------
#
# ++ Learning rate reduced, now at = 0.000495
# Batch PDE Loss = 4.944401649377638e-06
#
# Batch Data Loss = 0.00010819332544393058
#
# ------------------------------------------------------------------
#
# |                      Epoch 70                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000490
# Batch PDE Loss = 4.771321883929787e-06
#
# Batch Data Loss = 0.00010722169721485925
#
# ------------------------------------------------------------------
#
# |                      Epoch 71                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000485
# Batch PDE Loss = 4.736076773858382e-06
#
# Batch Data Loss = 0.00010676268798837893
#
# ------------------------------------------------------------------
#
# |                      Epoch 72                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000480
# Batch PDE Loss = 4.748068696123863e-06
#
# Batch Data Loss = 0.00010896144430685631
#
# ------------------------------------------------------------------
#
# |                      Epoch 73                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000475
# Batch PDE Loss = 4.507518078575045e-06
#
# Batch Data Loss = 0.00010649228377207047
#
# ------------------------------------------------------------------
#
# |                      Epoch 74                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000471
# Batch PDE Loss = 4.451837873284055e-06
#
# Batch Data Loss = 0.00010623392351865333
#
# ------------------------------------------------------------------
#
# |                      Epoch 75                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000466
# Batch PDE Loss = 4.342252484959996e-06
#
# Batch Data Loss = 0.00010655149025328722
#
# ------------------------------------------------------------------
#
# |                      Epoch 76                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000461
# Batch PDE Loss = 4.4342701678277265e-06
#
# Batch Data Loss = 0.00011139926991439442
#
# ------------------------------------------------------------------
#
# |                      Epoch 77                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000457
# Batch PDE Loss = 4.6110927734451e-06
#
# Batch Data Loss = 0.00010627311629833956
#
# ------------------------------------------------------------------
#
# |                      Epoch 78                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000452
# Batch PDE Loss = 4.39740272022617e-06
#
# Batch Data Loss = 0.00010663787216252597
#
# ------------------------------------------------------------------
#
# |                      Epoch 79                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000448
# Batch PDE Loss = 4.197106664973461e-06
#
# Batch Data Loss = 0.00010711645712560717
#
# ------------------------------------------------------------------
#
# |                      Epoch 80                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000443
# Batch PDE Loss = 4.203112706108278e-06
#
# Batch Data Loss = 0.0001061703155249483
#
# ------------------------------------------------------------------
#
# |                      Epoch 81                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000439
# Batch PDE Loss = 4.238168414062856e-06
#
# Batch Data Loss = 0.00010505525459354948
#
# ------------------------------------------------------------------
#
# |                      Epoch 82                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000434
# Batch PDE Loss = 4.18556298278843e-06
#
# Batch Data Loss = 0.00010663156882639272
#
# ------------------------------------------------------------------
#
# |                      Epoch 83                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000430
# Batch PDE Loss = 4.196968153734932e-06
#
# Batch Data Loss = 0.00010711734967319419
#
# ------------------------------------------------------------------
#
# |                      Epoch 84                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000426
# Batch PDE Loss = 4.336250689345747e-06
#
# Batch Data Loss = 0.0001063683720981434
#
# ------------------------------------------------------------------
#
# |                      Epoch 85                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000421
# Batch PDE Loss = 4.204640249891721e-06
#
# Batch Data Loss = 0.00010585957103399063
#
# ------------------------------------------------------------------
#
# |                      Epoch 86                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000417
# Batch PDE Loss = 4.060307845643803e-06
#
# Batch Data Loss = 0.00010540284974447916
#
# ------------------------------------------------------------------
#
# |                      Epoch 87                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000413
# Batch PDE Loss = 4.056793293994558e-06
#
# Batch Data Loss = 0.0001063224529703536
#
# ------------------------------------------------------------------
#
# |                      Epoch 88                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000409
# Batch PDE Loss = 4.269308857163743e-06
#
# Batch Data Loss = 0.00010884039255068842
#
# ------------------------------------------------------------------
#
# |                      Epoch 89                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000405
# Batch PDE Loss = 4.007523392822668e-06
#
# Batch Data Loss = 0.00010616469761378328
#
# ------------------------------------------------------------------
#
# |                      Epoch 90                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000401
# Batch PDE Loss = 3.901747304916419e-06
#
# Batch Data Loss = 0.00010556674105026126
#
# ------------------------------------------------------------------
#
# |                      Epoch 91                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000397
# Batch PDE Loss = 3.904875625605463e-06
#
# Batch Data Loss = 0.00010563371277915369
#
# ------------------------------------------------------------------
#
# |                      Epoch 92                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
# ----------
#
# ++ Learning rate reduced, now at = 0.000393
# Batch PDE Loss = 3.755739895839582e-06
#
# Batch Data Loss = 0.00010652870534980266
#
# ------------------------------------------------------------------
#
# |                      Epoch 93                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000389
# Batch PDE Loss = 3.714974208102627e-06
#
# Batch Data Loss = 0.0001053583210488193
#
# ------------------------------------------------------------------
#
# |                      Epoch 94                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000385
# Batch PDE Loss = 3.799801757713289e-06
#
# Batch Data Loss = 0.00010604946272509526
#
# ------------------------------------------------------------------
#
# |                      Epoch 95                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000381
# Batch PDE Loss = 3.5904336663673526e-06
#
# Batch Data Loss = 0.00010532059055113653
#
# ------------------------------------------------------------------
#
# |                      Epoch 96                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000377
# Batch PDE Loss = 3.7258957575358715e-06
#
# Batch Data Loss = 0.00010520725585069725
#
# ------------------------------------------------------------------
#
# |                      Epoch 97                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000373
# Batch PDE Loss = 3.6484407537720028e-06
#
# Batch Data Loss = 0.00010489861525188424
#
# ------------------------------------------------------------------
#
# |                      Epoch 98                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000370
# Batch PDE Loss = 3.5945483581919143e-06
#
# Batch Data Loss = 0.00010613503192694203
#
# ------------------------------------------------------------------
#
# |                      Epoch 99                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000366
# Batch PDE Loss = 3.5589842676991646e-06
#
# Batch Data Loss = 0.00010725999839050044
#
# ------------------------------------------------------------------
#
# |                      Epoch 100                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000362
# Batch PDE Loss = 3.471792881383292e-06
#
# Batch Data Loss = 0.00010659605438774265
#
# ------------------------------------------------------------------
#
# |                      Epoch 101                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000359
# Batch PDE Loss = 3.4714041078217436e-06
#
# Batch Data Loss = 0.00010490958639140071
#
# ------------------------------------------------------------------
#
# |                      Epoch 102                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000355
# Batch PDE Loss = 3.4894599482657657e-06
#
# Batch Data Loss = 0.00010461150168936146
#
# ------------------------------------------------------------------
#
# |                      Epoch 103                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000352
# Batch PDE Loss = 3.3224306083685896e-06
#
# Batch Data Loss = 0.00010421113689673197
#
# ------------------------------------------------------------------
#
# |                      Epoch 104                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000348
# Batch PDE Loss = 3.25248143483514e-06
#
# Batch Data Loss = 0.0001040828068859358
#
# ------------------------------------------------------------------
#
# |                      Epoch 105                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000345
# Batch PDE Loss = 3.1488195020603406e-06
#
# Batch Data Loss = 0.00010424875308161876
#
# ------------------------------------------------------------------
#
# |                      Epoch 106                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000341
# Batch PDE Loss = 3.238198571285608e-06
#
# Batch Data Loss = 0.00010517765103936067
#
# ------------------------------------------------------------------
#
# |                      Epoch 107                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000338
# Batch PDE Loss = 3.1298275655941212e-06
#
# Batch Data Loss = 0.00010549301309782893
#
# ------------------------------------------------------------------
#
# |                      Epoch 108                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000334
# Batch PDE Loss = 3.0768907807534372e-06
#
# Batch Data Loss = 0.00010448811171704368
#
# ------------------------------------------------------------------
#
# |                      Epoch 109                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000331
# Batch PDE Loss = 3.0164266299130837e-06
#
# Batch Data Loss = 0.00010410774282660009
#
# ------------------------------------------------------------------
#
# |                      Epoch 110                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000328
# Batch PDE Loss = 3.0003346773860312e-06
#
# Batch Data Loss = 0.00010373746361890344
#
# ------------------------------------------------------------------
#
# |                      Epoch 111                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000324
# Batch PDE Loss = 2.9842604873999904e-06
#
# Batch Data Loss = 0.0001071591913308705
#
# ------------------------------------------------------------------
#
# |                      Epoch 112                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000321
# Batch PDE Loss = 3.046856538127004e-06
#
# Batch Data Loss = 0.00010474946688024259
#
# ------------------------------------------------------------------
#
# |                      Epoch 113                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000318
# Batch PDE Loss = 2.871390259595707e-06
#
# Batch Data Loss = 0.00010424943801197476
#
# ------------------------------------------------------------------
#
# |                      Epoch 114                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000315
# Batch PDE Loss = 2.92417491590939e-06
#
# Batch Data Loss = 0.00010520254878003544
#
# ------------------------------------------------------------------
#
# |                      Epoch 115                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
# ----------
#
# ++ Learning rate reduced, now at = 0.000312
# Batch PDE Loss = 2.9330279623184104e-06
#
# Batch Data Loss = 0.00010491955399083413
#
# ------------------------------------------------------------------
#
# |                      Epoch 116                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000309
# Batch PDE Loss = 2.8983877510528817e-06
#
# Batch Data Loss = 0.00010519523262643026
#
# ------------------------------------------------------------------
#
# |                      Epoch 117                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000305
# Batch PDE Loss = 2.89185170221692e-06
#
# Batch Data Loss = 0.00010531814776547597
#
# ------------------------------------------------------------------
#
# |                      Epoch 118                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000302
# Batch PDE Loss = 2.8224132732876956e-06
#
# Batch Data Loss = 0.0001039001789703724
#
# ------------------------------------------------------------------
#
# |                      Epoch 119                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000299
# Batch PDE Loss = 2.743276302237724e-06
#
# Batch Data Loss = 0.00010383832882383073
#
# ------------------------------------------------------------------
#
# |                      Epoch 120                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000296
# Batch PDE Loss = 2.7776564729086963e-06
#
# Batch Data Loss = 0.00010507383218339186
#
# ------------------------------------------------------------------
#
# |                      Epoch 121                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000293
# Batch PDE Loss = 2.761735827325643e-06
#
# Batch Data Loss = 0.00010496251496630269
#
# ------------------------------------------------------------------
#
# |                      Epoch 122                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000290
# Batch PDE Loss = 2.6942516605814815e-06
#
# Batch Data Loss = 0.00010608172402653854
#
# ------------------------------------------------------------------
#
# |                      Epoch 123                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000288
# Batch PDE Loss = 2.666231250562132e-06
#
# Batch Data Loss = 0.00010375272039446044
#
# ------------------------------------------------------------------
#
# |                      Epoch 124                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000285
# Batch PDE Loss = 2.6705230619774606e-06
#
# Batch Data Loss = 0.00010438848363852984
#
# ------------------------------------------------------------------
#
# |                      Epoch 125                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000282
# Batch PDE Loss = 2.606043252768764e-06
#
# Batch Data Loss = 0.00010433754072710281
#
# ------------------------------------------------------------------
#
# |                      Epoch 126                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000279
# Batch PDE Loss = 2.5695268949053445e-06
#
# Batch Data Loss = 0.00010383646056767296
#
# ------------------------------------------------------------------
#
# |                      Epoch 127                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000276
# Batch PDE Loss = 2.570648976221227e-06
#
# Batch Data Loss = 0.00010442602342400176
#
# ------------------------------------------------------------------
#
# |                      Epoch 128                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000273
# Batch PDE Loss = 2.62701114043567e-06
#
# Batch Data Loss = 0.00010501702668494076
#
# ------------------------------------------------------------------
#
# |                      Epoch 129                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000271
# Batch PDE Loss = 2.530590957492484e-06
#
# Batch Data Loss = 0.0001041881873507351
#
# ------------------------------------------------------------------
#
# |                      Epoch 130                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000268
# Batch PDE Loss = 2.6016509087673757e-06
#
# Batch Data Loss = 0.00010410680519800041
#
# ------------------------------------------------------------------
#
# |                      Epoch 131                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000265
# Batch PDE Loss = 2.455570044229501e-06
#
# Batch Data Loss = 0.00010378677789598588
#
# ------------------------------------------------------------------
#
# |                      Epoch 132                                  |
#
# ...
#
# |                      Epoch 157                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000204
# Batch PDE Loss = 2.0761764968763504e-06
#
# Batch Data Loss = 0.00010331806105783922
#
# ------------------------------------------------------------------
#
# |                      Epoch 158                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000202
# Batch PDE Loss = 1.9459013050179197e-06
#
# Batch Data Loss = 0.00010277758556319579
#
# ------------------------------------------------------------------
#
# |                      Epoch 159                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000200
# Batch PDE Loss = 1.9523491364622245e-06
#
# Batch Data Loss = 0.00010451188427117366
#
# ------------------------------------------------------------------
#
# |                      Epoch 160                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000198
# Batch PDE Loss = 1.897059626745433e-06
#
# Batch Data Loss = 0.00010309044312478656
#
# ------------------------------------------------------------------
#
# |                      Epoch 161                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
# ----------
#
# ++ Learning rate reduced, now at = 0.000196
# Batch PDE Loss = 1.8889617039567812e-06
#
# Batch Data Loss = 0.00010274009896447554
#
# ------------------------------------------------------------------
#
# |                      Epoch 162                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000194
# Batch PDE Loss = 1.9303257180987546e-06
#
# Batch Data Loss = 0.00010268702774532885
#
# ------------------------------------------------------------------
#
# |                      Epoch 163                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000192
# Batch PDE Loss = 1.8891718939593985e-06
#
# Batch Data Loss = 0.00010312941935757297
#
# ------------------------------------------------------------------
#
# |                      Epoch 164                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000190
# Batch PDE Loss = 1.89055081001492e-06
#
# Batch Data Loss = 0.00010272562499397417
#
# ------------------------------------------------------------------
#
# |                      Epoch 165                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000189
# Batch PDE Loss = 1.8457430418376397e-06
#
# Batch Data Loss = 0.0001032966202131134
#
# ------------------------------------------------------------------
#
# |                      Epoch 166                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000187
# Batch PDE Loss = 1.8299185811275371e-06
#
# Batch Data Loss = 0.00010219698480872965
#
# ------------------------------------------------------------------
#
# |                      Epoch 167                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000185
# Batch PDE Loss = 1.7961076161067147e-06
#
# Batch Data Loss = 0.00010286381756592287
#
# ------------------------------------------------------------------
#
# |                      Epoch 168                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000183
# Batch PDE Loss = 1.7960154252036115e-06
#
# Batch Data Loss = 0.00010306731157482607
#
# ------------------------------------------------------------------
#
# |                      Epoch 169                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000181
# Batch PDE Loss = 1.7475039704461494e-06
#
# Batch Data Loss = 0.0001025306803428368
#
# ------------------------------------------------------------------
#
# |                      Epoch 170                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000179
# Batch PDE Loss = 1.822312322798597e-06
#
# Batch Data Loss = 0.00010306202236506908
#
# ------------------------------------------------------------------
#
# |                      Epoch 171                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000178
# Batch PDE Loss = 1.744901547944668e-06
#
# Batch Data Loss = 0.00010214081681354612
#
# ------------------------------------------------------------------
#
# |                      Epoch 172                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000176
# Batch PDE Loss = 1.8107794342309074e-06
#
# Batch Data Loss = 0.0001028935776493358
#
# ------------------------------------------------------------------
#
# |                      Epoch 173                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000174
# Batch PDE Loss = 1.7873705266071075e-06
#
# Batch Data Loss = 0.00010412204604576428
#
# ------------------------------------------------------------------
#
# |                      Epoch 174                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000172
# Batch PDE Loss = 1.7235653076528857e-06
#
# Batch Data Loss = 0.00010267694567452686
#
# ------------------------------------------------------------------
#
# |                      Epoch 175                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000171
# Batch PDE Loss = 1.741386617147731e-06
#
# Batch Data Loss = 0.00010294574768821803
#
# ------------------------------------------------------------------
#
# |                      Epoch 176                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000169
# Batch PDE Loss = 1.710918520854611e-06
#
# Batch Data Loss = 0.0001022594927327914
#
# ------------------------------------------------------------------
#
# |                      Epoch 177                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000167
# Batch PDE Loss = 1.7022339156761787e-06
#
# Batch Data Loss = 0.00010297716307020218
#
# ------------------------------------------------------------------
#
# |                      Epoch 178                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000165
# Batch PDE Loss = 1.6586387726617427e-06
#
# Batch Data Loss = 0.00010301521905108997
#
# ------------------------------------------------------------------
#
# |                      Epoch 179                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000164
# Batch PDE Loss = 1.699759901952877e-06
#
# Batch Data Loss = 0.00010267374250825959
#
# ------------------------------------------------------------------
#
# |                      Epoch 180                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000162
# Batch PDE Loss = 1.6571532382430504e-06
#
# Batch Data Loss = 0.00010215120769623024
#
# ------------------------------------------------------------------
#
# |                      Epoch 181                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000161
# Batch PDE Loss = 1.6699433138831843e-06
#
# Batch Data Loss = 0.00010263377739834945
#
# ------------------------------------------------------------------
#
# |                      Epoch 182                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000159
# Batch PDE Loss = 1.7181934997249115e-06
#
# Batch Data Loss = 0.00010267099827768299
#
# ------------------------------------------------------------------
#
# |                      Epoch 183                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000157
# Batch PDE Loss = 1.6251519167292352e-06
#
# Batch Data Loss = 0.00010251879429537846
#
# ------------------------------------------------------------------
#
# |                      Epoch 184                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
# ----------
#
# ++ Learning rate reduced, now at = 0.000156
# Batch PDE Loss = 1.5799039935840617e-06
#
# Batch Data Loss = 0.00010195259529506384
#
# ------------------------------------------------------------------
#
# |                      Epoch 185                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000154
# Batch PDE Loss = 1.5611497506917623e-06
#
# Batch Data Loss = 0.0001023074030511524
#
# ------------------------------------------------------------------
#
# |                      Epoch 186                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000153
# Batch PDE Loss = 1.5917513480893805e-06
#
# Batch Data Loss = 0.00010222261777219084
#
# ------------------------------------------------------------------
#
# |                      Epoch 187                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000151
# Batch PDE Loss = 1.5716236502797895e-06
#
# Batch Data Loss = 0.00010261214543757259
#
# ------------------------------------------------------------------
#
# |                      Epoch 188                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000150
# Batch PDE Loss = 1.5603097013876817e-06
#
# Batch Data Loss = 0.00010252425413936421
#
# ------------------------------------------------------------------
#
# |                      Epoch 189                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000148
# Batch PDE Loss = 1.574106372205039e-06
#
# Batch Data Loss = 0.00010220293263485363
#
# ------------------------------------------------------------------
#
# |                      Epoch 190                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000147
# Batch PDE Loss = 1.5798037253832258e-06
#
# Batch Data Loss = 0.00010210017033162759
#
# ------------------------------------------------------------------
#
# |                      Epoch 191                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000145
# Batch PDE Loss = 1.5917981552810046e-06
#
# Batch Data Loss = 0.00010206726760438007
#
# ------------------------------------------------------------------
#
# |                      Epoch 192                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000144
# Batch PDE Loss = 1.5319725255943968e-06
#
# Batch Data Loss = 0.00010357712660450425
#
# ------------------------------------------------------------------
#
# |                      Epoch 193                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000142
# Batch PDE Loss = 1.5422586917856756e-06
#
# Batch Data Loss = 0.00010218175735736614
#
# ------------------------------------------------------------------
#
# |                      Epoch 194                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000141
# Batch PDE Loss = 1.5029228146108272e-06
#
# Batch Data Loss = 0.00010211735703851137
#
# ------------------------------------------------------------------
#
# |                      Epoch 195                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000139
# Batch PDE Loss = 1.4955876239411032e-06
#
# Batch Data Loss = 0.00010204858418339472
#
# ------------------------------------------------------------------
#
# |                      Epoch 196                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000138
# Batch PDE Loss = 1.4912480160699157e-06
#
# Batch Data Loss = 0.00010220203951297093
#
# ------------------------------------------------------------------
#
# |                      Epoch 197                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000137
# Batch PDE Loss = 1.474055089052627e-06
#
# Batch Data Loss = 0.00010246060391354158
#
# ------------------------------------------------------------------
#
# |                      Epoch 198                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000135
# Batch PDE Loss = 1.4726680287522268e-06
#
# Batch Data Loss = 0.00010314907517045968
#
# ------------------------------------------------------------------
#
# |                      Epoch 199                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000134
# Batch PDE Loss = 1.469513307466732e-06
#
# Batch Data Loss = 0.00010219521679266897
#
# ------------------------------------------------------------------
#
# |                      Epoch 200                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000133
# Batch PDE Loss = 1.4722215642677413e-06
#
# Batch Data Loss = 0.00010299827326051263

# %%
# visualize losses
plt.figure(1, figsize=(16, 8));
plt.plot(np.log10(info["pde_loss"]), lw=2, color="red");
plt.title("PDE Loss vs. Epoch");

plt.figure(2, figsize=(16, 8));
plt.plot(np.log10(info["data_loss"]), lw=2, color="blue");
plt.title("Data Loss vs. Epoch");

query = cartesian_data(pinn.tgrid, pinn.xgrid)
p_pred = pinn(query).reshape(pinn.nx, pinn.nt).T.detach().numpy()

# grids
tgrid = pinn.tgrid.detach().numpy()
xgrid = pinn.xgrid.detach().numpy()

p_exact = pinn.raw_data["pmc"]
dx = pinn.dx.item()
dt = pinn.dt.item()

# %%
nx = 400
xgrid_fine = np.linspace(-10.0, 10.0, nx)
xgrid_fine = torch.tensor(xgrid_fine)
dx = xgrid_fine[1]-xgrid_fine[0]
nt = 1000
tgrid_fine = np.linspace(0., 10.0, nt)
tgrid_fine = torch.tensor(tgrid_fine)
dt = tgrid_fine[1]-tgrid_fine[0]

query_fine = cartesian_data(tgrid_fine, xgrid_fine)

G_pred_fine = pinn.G_nn(query_fine[:, 1][:, None]).reshape(nx, nt).T.detach().numpy()
p_pred_fine = pinn(query_fine).reshape(nx, nt).T.detach().numpy()

# %%
plt.contourf(G_pred_fine); plt.colorbar();

# %%
plt.figure(1);
plt.plot(xgrid_fine, G_pred_fine[0, :], color="red");
plt.plot(xgrid_fine, np.ones_like(xgrid_fine), "--", color="blue", lw=5.0, alpha=0.5, label="exact");
plt.ylim([0.9, 1.1])
plt.legend(); 
plt.xlabel(r"$x$");
plt.ylabel(r"$G(x)$");
