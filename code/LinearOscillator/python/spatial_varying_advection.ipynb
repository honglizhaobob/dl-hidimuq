# %% [markdown]
# ## Learning a variable coefficient advection
#
# To verify that our PINN implementation is working well, we test the PINN on the following problem:
# $$
#     \begin{cases}
#         u_t + a(x)u_x = 0\\
#         \lim_{|x|\rightarrow\infty}u(t, x) = 0\\
#         u(0, x) = u_0(x)
#     \end{cases}
# $$ where $u_0 = \mathcal{N}(x|0, 1)$. Here $a(x)$ is a function in space.

# %%
from PINN.AdvectionNet import *
# Testing
import matplotlib.pyplot as plt
import torch
import numpy as np
import scipy

# set random seeds
np.random.seed(10)
torch.manual_seed(10);
import numpy as np    
import matplotlib.pyplot as plt

# %%
# define computational grids
xmin, xmax = -4., 4.
nx = 2000
xgrid = np.linspace(xmin, xmax, nx)

dt = 0.001
tmax = 5.0
tgrid = np.arange(0, tmax, dt)
nt = len(tgrid)

# define advection function
v = lambda x: np.sin(-x)

# create data simulator
scheme = LinearAdvection1d(v, tgrid, xgrid)

# %%
#############  
# Start of the code
###################

# initial value
x = xgrid
u0=(1/(np.sqrt(2*np.pi)))*np.exp(-0.5*((x)**2))
u_sol = np.zeros([nt, nx])
u_prev = u0
for i in range(nt):
    u_sol[i, :] = u_prev
    u_new = scheme.step(u_prev)
    u_prev = u_new

sigma = 0.0
u_sol = u_sol + sigma * np.random.randn(u_sol.shape[0], u_sol.shape[1])

# save data for testing
scipy.io.savemat("../data/LinearOscillator/Space_Advection.mat", {
    "xgrid": x.reshape(1, -1),
    "tgrid": tgrid.reshape(1, -1),
    "pmc": u_sol
})

# save a smaller dataset
subsample_t = 5
subsample_x = 5
xgrid_small = x.reshape(1, -1)[:, 0:-1:subsample_x].squeeze(),
tgrid_small = tgrid.reshape(1, -1)[:, 0:-1:subsample_t].squeeze()
u_sol_small = u_sol[0:-1:subsample_t, 0:-1:subsample_x]
scipy.io.savemat("../data/LinearOscillator/Space_Advection_small.mat", {
    "xgrid": xgrid_small,
    "tgrid": tgrid_small,
    "pmc": u_sol_small
})
print("Training data size = {}\n".format(u_sol_small.shape))
# Out:
# Training data size = (1000, 400)

# %%
# visualize solution
import time
import pylab as pl
from IPython import display
from IPython.display import clear_output

dt_small = tgrid_small[1]-tgrid_small[0]
for i in range(len(tgrid_small)):
    plt.figure(1);
    plt.plot(xgrid_small[0], u_sol_small[i, :], color="red");
    plt.title(r"Time $t = {}$".format((i+1)*dt_small));
    display.clear_output(wait=True);
    display.display(pl.gcf());
    plt.clf();
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [84], in <cell line: 8>()
#      11 plt.title(r"Time $t = {}$".format((i+1)*dt_small));
#      12 display.clear_output(wait=True);
# ---> 13 display.display(pl.gcf());
#      14 plt.clf()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/formatters.py:178, in DisplayFormatter.format(self, obj, include, exclude)
#     176 md = None
#     177 try:
# --> 178     data = formatter(obj)
#     179 except:
#     180     # FIXME: log the exception
#     181     raise
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/formatters.py:222, in catch_format_error(method, self, *args, **kwargs)
#     220 """show traceback on failed format call"""
#     221 try:
# --> 222     r = method(self, *args, **kwargs)
#     223 except NotImplementedError:
#     224     # don't warn on NotImplementedErrors
#     225     return self._check_return(None, args[0])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/formatters.py:339, in BaseFormatter.__call__(self, obj)
#     337     pass
#     338 else:
# --> 339     return printer(obj)
#     340 # Finally look for special method names
#     341 method = get_real_method(obj, self.print_method)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     148     from matplotlib.backend_bases import FigureCanvasBase
#     149     FigureCanvasBase(fig)
# --> 151 fig.canvas.print_figure(bytes_io, **kw)
#     152 data = bytes_io.getvalue()
#     153 if fmt == 'svg':
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backend_bases.py:2295, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2289     renderer = _get_renderer(
#    2290         self.figure,
#    2291         functools.partial(
#    2292             print_method, orientation=orientation)
#    2293     )
#    2294     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2295         self.figure.draw(renderer)
#    2297 if bbox_inches:
#    2298     if bbox_inches == "tight":
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py:74, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      72 @wraps(draw)
#      73 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74     result = draw(artist, renderer, *args, **kwargs)
#      75     if renderer._rasterizing:
#      76         renderer.stop_rasterizing()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/figure.py:2845, in Figure.draw(self, renderer)
#    2842         # ValueError can occur when resizing a window.
#    2844 self.patch.draw(renderer)
# -> 2845 mimage._draw_list_compositing_images(
#    2846     renderer, self, artists, self.suppressComposite)
#    2848 for sfig in self.subfigs:
#    2849     sfig.draw(renderer)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py:3091, in _AxesBase.draw(self, renderer)
#    3088         a.draw(renderer)
#    3089     renderer.stop_rasterizing()
# -> 3091 mimage._draw_list_compositing_images(
#    3092     renderer, self, artists, self.figure.suppressComposite)
#    3094 renderer.close_group('axes')
#    3095 self.stale = False
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py:1159, in Axis.draw(self, renderer, *args, **kwargs)
#    1156 renderer.open_group(__name__, gid=self.get_gid())
#    1158 ticks_to_draw = self._update_ticks()
# -> 1159 ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1160                                                         renderer)
#    1162 for tick in ticks_to_draw:
#    1163     tick.draw(renderer)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py:1085, in Axis._get_tick_bboxes(self, ticks, renderer)
#    1083 def _get_tick_bboxes(self, ticks, renderer):
#    1084     """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1085     return ([tick.label1.get_window_extent(renderer)
#    1086              for tick in ticks if tick.label1.get_visible()],
#    1087             [tick.label2.get_window_extent(renderer)
#    1088              for tick in ticks if tick.label2.get_visible()])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py:1085, in <listcomp>(.0)
#    1083 def _get_tick_bboxes(self, ticks, renderer):
#    1084     """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1085     return ([tick.label1.get_window_extent(renderer)
#    1086              for tick in ticks if tick.label1.get_visible()],
#    1087             [tick.label2.get_window_extent(renderer)
#    1088              for tick in ticks if tick.label2.get_visible()])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/text.py:910, in Text.get_window_extent(self, renderer, dpi)
#     907     raise RuntimeError('Cannot get window extent w/o renderer')
#     909 with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 910     bbox, info, descent = self._get_layout(self._renderer)
#     911     x, y = self.get_unitless_position()
#     912     x, y = self.get_transform().transform((x, y))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/text.py:317, in Text._get_layout(self, renderer)
#     315 clean_line, ismath = self._preprocess_math(line)
#     316 if clean_line:
# --> 317     w, h, d = renderer.get_text_width_height_descent(
#     318         clean_line, self._fontproperties, ismath=ismath)
#     319 else:
#     320     w = h = d = 0
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:269, in RendererAgg.get_text_width_height_descent(self, s, prop, ismath)
#     266     return width, height, descent
#     268 flags = get_hinting_flag()
# --> 269 font = self._get_agg_font(prop)
#     270 font.set_text(s, 0.0, flags=flags)
#     271 w, h = font.get_width_height()  # width and height of unrotated string
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:306, in RendererAgg._get_agg_font(self, prop)
#     303 fname = findfont(prop)
#     304 font = get_font(fname)
# --> 306 font.clear()
#     307 size = prop.get_size_in_points()
#     308 font.set_size(size, self.dpi)
#
# KeyboardInterrupt:

# %%
# testing PINN # inverse problem with PINN
#data_path = "../data/LinearOscillator/Pure_Advection.mat"
# subsampled spatial training data
data_path = "../data/LinearOscillator/Space_Advection_small.mat"
# create PINN
pinn = AdvectionNet(indim=2, outdim=1, data_path=data_path, scheduler="ExponentialLR")
# testing training
info = train(
    pinn, pinn.optimizer, pinn.scheduler, batch_size=2**9,
    epochs=200, batch_print=200, mode="all"
)
# Out:
# ------------------------------------------------------------
#
# => Data Loaded at: ../data/LinearOscillator/Space_Advection_small.mat
#
# ----> Total Number of observations = 397602
#
# ------------------------------------------------------------
#
# ------------------------------------------------------------------
#
# |                      Epoch 1                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000980
# Batch PDE Loss = 0.0002002879491957297
#
# Batch Data Loss = 0.0005258100410842448
#
# ------------------------------------------------------------------
#
# |                      Epoch 2                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000970
# Batch PDE Loss = 0.00011636327434729367
#
# Batch Data Loss = 0.00013721536748219321
#
# ------------------------------------------------------------------
#
# |                      Epoch 3                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000961
# Batch PDE Loss = 0.00010037913470151787
#
# Batch Data Loss = 0.0001080396514953291
#
# ------------------------------------------------------------------
#
# |                      Epoch 4                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000951
# Batch PDE Loss = 9.60875076237406e-05
#
# Batch Data Loss = 0.00010020260450297796
#
# ------------------------------------------------------------------
#
# |                      Epoch 5                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000941
# Batch PDE Loss = 8.933320236427298e-05
#
# Batch Data Loss = 8.910221284416985e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 6                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000932
# Batch PDE Loss = 8.674241565614544e-05
#
# Batch Data Loss = 8.092761383189901e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 7                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000923
# Batch PDE Loss = 8.553630696916851e-05
#
# Batch Data Loss = 7.543285823215467e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 8                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000914
# Batch PDE Loss = 8.550252427448298e-05
#
# Batch Data Loss = 7.585805681407672e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 9                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000904
# Batch PDE Loss = 8.510679829987417e-05
#
# Batch Data Loss = 7.444403421335545e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 10                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000895
# Batch PDE Loss = 8.240065569203236e-05
#
# Batch Data Loss = 6.859986655696613e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 11                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000886
# Batch PDE Loss = 7.420485022221445e-05
#
# Batch Data Loss = 5.910175873657696e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 12                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000878
# Batch PDE Loss = 6.796441898775159e-05
#
# Batch Data Loss = 5.020040044229809e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 13                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000869
# Batch PDE Loss = 6.447890613386857e-05
#
# Batch Data Loss = 4.8017906735732563e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 14                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000860
# Batch PDE Loss = 6.137229486601223e-05
#
# Batch Data Loss = 4.5034249044579795e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 15                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000851
# Batch PDE Loss = 6.242275113713487e-05
#
# Batch Data Loss = 4.3024172199671325e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 16                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000843
# Batch PDE Loss = 6.145476921629656e-05
#
# Batch Data Loss = 4.3624520933247305e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 17                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000835
# Batch PDE Loss = 5.6657835969929283e-05
#
# Batch Data Loss = 3.652423417214478e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 18                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000826
# Batch PDE Loss = 5.7168796224727026e-05
#
# Batch Data Loss = 3.4595038044747355e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 19                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000818
# Batch PDE Loss = 5.467459783726288e-05
#
# Batch Data Loss = 3.195147784652843e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 20                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000810
# Batch PDE Loss = 5.087842434780129e-05
#
# Batch Data Loss = 3.0464102978637023e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 21                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000802
# Batch PDE Loss = 5.201522329371541e-05
#
# Batch Data Loss = 2.9304059667610184e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 22                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000794
# Batch PDE Loss = 4.9818690599100234e-05
#
# Batch Data Loss = 2.846067382372921e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 23                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000786
# Batch PDE Loss = 4.813423145628246e-05
#
# Batch Data Loss = 2.62582618070779e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 24                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000778
# Batch PDE Loss = 5.0930033352052276e-05
#
# Batch Data Loss = 2.728736314828573e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 25                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000770
# Batch PDE Loss = 5.537781547359086e-05
#
# Batch Data Loss = 3.212807022129549e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 26                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000762
# Batch PDE Loss = 5.637345219311508e-05
#
# Batch Data Loss = 3.166524875719867e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 27                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000755
# Batch PDE Loss = 5.65794078576211e-05
#
# Batch Data Loss = 3.157099857944019e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 28                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000747
# Batch PDE Loss = 5.260372123997718e-05
#
# Batch Data Loss = 2.8812997964372257e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 29                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000740
# Batch PDE Loss = 5.2482629135067634e-05
#
# Batch Data Loss = 2.82358496139165e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 30                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000732
# Batch PDE Loss = 5.035331367948019e-05
#
# Batch Data Loss = 2.7532541511333726e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 31                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000725
# Batch PDE Loss = 4.9792189533537296e-05
#
# Batch Data Loss = 2.714345784117875e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 32                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000718
# Batch PDE Loss = 4.912743562955121e-05
#
# Batch Data Loss = 2.6253116897201396e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 33                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000711
# Batch PDE Loss = 4.906431974576846e-05
#
# Batch Data Loss = 2.522355711783017e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 34                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000703
# Batch PDE Loss = 4.979990202475491e-05
#
# Batch Data Loss = 2.623621473152527e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 35                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000696
# Batch PDE Loss = 5.0015959291357173e-05
#
# Batch Data Loss = 2.6025034025506932e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 36                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000689
# Batch PDE Loss = 5.020819128678113e-05
#
# Batch Data Loss = 2.6460239540021964e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 37                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000683
# Batch PDE Loss = 5.129576997697589e-05
#
# Batch Data Loss = 2.6804832530019007e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 38                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000676
# Batch PDE Loss = 4.961968393067349e-05
#
# Batch Data Loss = 2.688359599374164e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 39                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000669
# Batch PDE Loss = 4.8855459095818374e-05
#
# Batch Data Loss = 2.5581468148526646e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 40                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000662
# Batch PDE Loss = 4.954266821667367e-05
#
# Batch Data Loss = 2.682943380097666e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 41                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000656
# Batch PDE Loss = 5.1352985694452335e-05
#
# Batch Data Loss = 2.7601714275320675e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 42                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000649
# Batch PDE Loss = 5.0141970361423626e-05
#
# Batch Data Loss = 2.7116501404429267e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 43                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000643
# Batch PDE Loss = 5.0660550420694354e-05
#
# Batch Data Loss = 2.6617221755670866e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 44                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000636
# Batch PDE Loss = 4.901193692717685e-05
#
# Batch Data Loss = 2.6038993725426375e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 45                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000630
# Batch PDE Loss = 4.9056724509187513e-05
#
# Batch Data Loss = 2.4762313984527774e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 46                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000624
# Batch PDE Loss = 4.8902655854914906e-05
#
# Batch Data Loss = 2.5273357244578002e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 47                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000617
# Batch PDE Loss = 4.659349911236881e-05
#
# Batch Data Loss = 2.4039470742191885e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 48                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000611
# Batch PDE Loss = 4.733291331018367e-05
#
# Batch Data Loss = 2.553293853555671e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 49                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000605
# Batch PDE Loss = 4.6798564911566684e-05
#
# Batch Data Loss = 2.4567822426736363e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 50                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000599
# Batch PDE Loss = 4.5068477830522806e-05
#
# Batch Data Loss = 2.3697344947692684e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 51                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000593
# Batch PDE Loss = 4.545431759462421e-05
#
# Batch Data Loss = 2.2758012149655527e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 52                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000587
# Batch PDE Loss = 4.578983926550828e-05
#
# Batch Data Loss = 2.2483518050202635e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 53                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000581
# Batch PDE Loss = 4.617035249752662e-05
#
# Batch Data Loss = 2.268988849415302e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 54                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000575
# Batch PDE Loss = 4.5407660029783955e-05
#
# Batch Data Loss = 2.32324372656403e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 55                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000570
# Batch PDE Loss = 4.8957168122673856e-05
#
# Batch Data Loss = 2.4610163043461876e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 56                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000564
# Batch PDE Loss = 5.1648465736344616e-05
#
# Batch Data Loss = 2.5648158357134045e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 57                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000558
# Batch PDE Loss = 4.982961388896456e-05
#
# Batch Data Loss = 2.6209139079655012e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 58                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000553
# Batch PDE Loss = 5.302999729613058e-05
#
# Batch Data Loss = 2.6912040526577786e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 59                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000547
# Batch PDE Loss = 5.44488553478988e-05
#
# Batch Data Loss = 2.7431444335723694e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 60                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000542
# Batch PDE Loss = 5.178409084621332e-05
#
# Batch Data Loss = 2.6801291544344666e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 61                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000536
# Batch PDE Loss = 5.06739381649186e-05
#
# Batch Data Loss = 2.595698991938017e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 62                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000531
# Batch PDE Loss = 5.067943319429159e-05
#
# Batch Data Loss = 2.6663132303401025e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 63                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000526
# Batch PDE Loss = 4.85670610618347e-05
#
# Batch Data Loss = 2.4374878919333585e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 64                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000520
# Batch PDE Loss = 4.8620783856584315e-05
#
# Batch Data Loss = 2.3821439338917793e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 65                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000515
# Batch PDE Loss = 4.886682084553501e-05
#
# Batch Data Loss = 2.362301756825518e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 66                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000510
# Batch PDE Loss = 4.8345416059203066e-05
#
# Batch Data Loss = 2.385320771354339e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 67                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000505
# Batch PDE Loss = 4.623826886025965e-05
#
# Batch Data Loss = 2.3377862195535545e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 68                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000500
# Batch PDE Loss = 4.627343000698746e-05
#
# Batch Data Loss = 2.2446386207725012e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 69                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000495
# Batch PDE Loss = 4.222284116330887e-05
#
# Batch Data Loss = 2.056981495338543e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 70                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000490
# Batch PDE Loss = 4.0713355444429066e-05
#
# Batch Data Loss = 1.9267505746997995e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 71                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000485
# Batch PDE Loss = 4.025149640813797e-05
#
# Batch Data Loss = 1.877135032561226e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 72                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000480
# Batch PDE Loss = 3.878274554901817e-05
#
# Batch Data Loss = 1.7533347281155225e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 73                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000475
# Batch PDE Loss = 3.868045346567479e-05
#
# Batch Data Loss = 1.6824933383417076e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 74                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000471
# Batch PDE Loss = 3.761998019627417e-05
#
# Batch Data Loss = 1.6118898474905702e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 75                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000466
# Batch PDE Loss = 3.8142311895966955e-05
#
# Batch Data Loss = 1.5975175341266956e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 76                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000461
# Batch PDE Loss = 3.8345761555896246e-05
#
# Batch Data Loss = 1.5463959870796546e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 77                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000457
# Batch PDE Loss = 3.775984053803971e-05
#
# Batch Data Loss = 1.529009609225351e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 78                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000452
# Batch PDE Loss = 3.848179404912234e-05
#
# Batch Data Loss = 1.5525834602186472e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 79                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000448
# Batch PDE Loss = 3.8937738356264066e-05
#
# Batch Data Loss = 1.6036939716900466e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 80                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000443
# Batch PDE Loss = 3.978699298887185e-05
#
# Batch Data Loss = 1.588319868335456e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 81                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000439
# Batch PDE Loss = 4.0135318463968874e-05
#
# Batch Data Loss = 1.5667915601851597e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 82                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000434
# Batch PDE Loss = 4.011839246251786e-05
#
# Batch Data Loss = 1.5712813174223122e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 83                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000430
# Batch PDE Loss = 3.9615301545596584e-05
#
# Batch Data Loss = 1.5699129504638248e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 84                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000426
# Batch PDE Loss = 3.976420797146335e-05
#
# Batch Data Loss = 1.554798428901209e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 85                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000421
# Batch PDE Loss = 4.00574556210319e-05
#
# Batch Data Loss = 1.5265542104193045e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 86                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000417
# Batch PDE Loss = 4.047280701541198e-05
#
# Batch Data Loss = 1.5433132078906097e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 87                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000413
# Batch PDE Loss = 4.108799046152711e-05
#
# Batch Data Loss = 1.5795095207558258e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 88                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000409
# Batch PDE Loss = 4.113779816817787e-05
#
# Batch Data Loss = 1.5655514868540748e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 89                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000405
# Batch PDE Loss = 3.96425041106839e-05
#
# Batch Data Loss = 1.5374379070930982e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 90                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000401
# Batch PDE Loss = 3.732665396434588e-05
#
# Batch Data Loss = 1.5042567332640845e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 91                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000397
# Batch PDE Loss = 3.689266738486113e-05
#
# Batch Data Loss = 1.4458606507025024e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 92                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000393
# Batch PDE Loss = 3.6246495467008145e-05
#
# Batch Data Loss = 1.4133726486903721e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 93                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000389
# Batch PDE Loss = 3.705540355395752e-05
#
# Batch Data Loss = 1.4118715859815918e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 94                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000385
# Batch PDE Loss = 3.716858719931564e-05
#
# Batch Data Loss = 1.3890964148854051e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 95                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000381
# Batch PDE Loss = 3.65526752835191e-05
#
# Batch Data Loss = 1.4061690209549843e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 96                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000377
# Batch PDE Loss = 3.6851473989168576e-05
#
# Batch Data Loss = 1.4194712886435747e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 97                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000373
# Batch PDE Loss = 3.687076307722034e-05
#
# Batch Data Loss = 1.373300535392247e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 98                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000370
# Batch PDE Loss = 3.706441211766765e-05
#
# Batch Data Loss = 1.383158900977812e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 99                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000366
# Batch PDE Loss = 3.7809267764838e-05
#
# Batch Data Loss = 1.3524202977800556e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 100                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000362
# Batch PDE Loss = 3.621768922060349e-05
#
# Batch Data Loss = 1.3100308230243866e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 101                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000359
# Batch PDE Loss = 3.364960246074119e-05
#
# Batch Data Loss = 1.2596594789417787e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 102                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000355
# Batch PDE Loss = 3.364899256716022e-05
#
# Batch Data Loss = 1.2305174942738132e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 103                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000352
# Batch PDE Loss = 3.390303006118554e-05
#
# Batch Data Loss = 1.2364042709983591e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 104                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000348
# Batch PDE Loss = 3.3464795407333514e-05
#
# Batch Data Loss = 1.1974869715064272e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 105                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000345
# Batch PDE Loss = 3.307121608375847e-05
#
# Batch Data Loss = 1.205291908651653e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 106                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000341
# Batch PDE Loss = 3.367384695085958e-05
#
# Batch Data Loss = 1.178226602029583e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 107                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000338
# Batch PDE Loss = 3.3628944032731826e-05
#
# Batch Data Loss = 1.1798818363647142e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 108                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000334
# Batch PDE Loss = 3.4366048235415895e-05
#
# Batch Data Loss = 1.1789801378566147e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 109                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000331
# Batch PDE Loss = 3.421375574546684e-05
#
# Batch Data Loss = 1.1373145577542767e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 110                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000328
# Batch PDE Loss = 3.4131169385326073e-05
#
# Batch Data Loss = 1.1315925240899294e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 111                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000324
# Batch PDE Loss = 3.488115717690572e-05
#
# Batch Data Loss = 1.1496385916405635e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 112                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000321
# Batch PDE Loss = 3.491841447232819e-05
#
# Batch Data Loss = 1.1693289994299813e-05
#
# ------------------------------------------------------------------
#
# |                      Epoch 113                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000318
# Batch PDE Loss = 3.652675452205585e-05
#
# ...
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000192
# Batch PDE Loss = 2.969418390581203e-05
#
# Batch Data Loss = 8.1945240503884e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 164                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000190
# Batch PDE Loss = 2.9521917946145983e-05
#
# Batch Data Loss = 8.012843610433596e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 165                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000189
# Batch PDE Loss = 3.0008814637779388e-05
#
# Batch Data Loss = 8.019832732107739e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 166                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000187
# Batch PDE Loss = 3.0804023339709856e-05
#
# Batch Data Loss = 8.684846658861448e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 167                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000185
# Batch PDE Loss = 3.025983414010999e-05
#
# Batch Data Loss = 8.358733262522258e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 168                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000183
# Batch PDE Loss = 3.08243691012391e-05
#
# Batch Data Loss = 8.502402905443823e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 169                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000181
# Batch PDE Loss = 3.1209662794744956e-05
#
# Batch Data Loss = 8.692732426093283e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 170                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000179
# Batch PDE Loss = 3.0929973770987484e-05
#
# Batch Data Loss = 8.526667237227558e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 171                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000178
# Batch PDE Loss = 2.981773189982051e-05
#
# Batch Data Loss = 8.123605773365054e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 172                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000176
# Batch PDE Loss = 2.9726262972643234e-05
#
# Batch Data Loss = 7.93800749282342e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 173                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000174
# Batch PDE Loss = 2.9359008067020984e-05
#
# Batch Data Loss = 7.90666042748553e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 174                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000172
# Batch PDE Loss = 2.8968026873849786e-05
#
# Batch Data Loss = 7.86145086596714e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 175                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000171
# Batch PDE Loss = 2.9533460219743194e-05
#
# Batch Data Loss = 7.849604152350559e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 176                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000169
# Batch PDE Loss = 2.987036742614634e-05
#
# Batch Data Loss = 7.924009560071473e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 177                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000167
# Batch PDE Loss = 3.0343639511532093e-05
#
# Batch Data Loss = 7.928126005038864e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 178                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000165
# Batch PDE Loss = 3.0619528422073384e-05
#
# Batch Data Loss = 8.029078488142904e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 179                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000164
# Batch PDE Loss = 3.060559980902236e-05
#
# Batch Data Loss = 8.057572919835276e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 180                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000162
# Batch PDE Loss = 3.0322427056104965e-05
#
# Batch Data Loss = 8.140048017717245e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 181                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000161
# Batch PDE Loss = 3.0488636645463836e-05
#
# Batch Data Loss = 8.052033869982206e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 182                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000159
# Batch PDE Loss = 3.302699582720846e-05
#
# Batch Data Loss = 8.81541790957001e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 183                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000157
# Batch PDE Loss = 3.202212597137807e-05
#
# Batch Data Loss = 9.151306419825944e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 184                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000156
# Batch PDE Loss = 3.252520211368825e-05
#
# Batch Data Loss = 9.652372591736605e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 185                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000154
# Batch PDE Loss = 3.17737387330434e-05
#
# Batch Data Loss = 9.519483697731284e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 186                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000153
# Batch PDE Loss = 3.120514054835375e-05
#
# Batch Data Loss = 9.442721935823709e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 187                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000151
# Batch PDE Loss = 3.183804357004056e-05
#
# Batch Data Loss = 9.396566060646071e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 188                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000150
# Batch PDE Loss = 3.1252620819739466e-05
#
# Batch Data Loss = 9.35320670849064e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 189                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000148
# Batch PDE Loss = 3.0885456409189596e-05
#
# Batch Data Loss = 9.222826812079723e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 190                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000147
# Batch PDE Loss = 3.114443980021969e-05
#
# Batch Data Loss = 9.228551589856522e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 191                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000145
# Batch PDE Loss = 3.064925651425286e-05
#
# Batch Data Loss = 9.251114047966827e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 192                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000144
# Batch PDE Loss = 3.0495593435761067e-05
#
# Batch Data Loss = 9.156127206585313e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 193                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000142
# Batch PDE Loss = 3.048509063494633e-05
#
# Batch Data Loss = 9.261295274465878e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 194                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000141
# Batch PDE Loss = 3.0338983298823783e-05
#
# Batch Data Loss = 9.18561777931061e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 195                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000139
# Batch PDE Loss = 3.0412146792708834e-05
#
# Batch Data Loss = 9.277230591943087e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 196                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000138
# Batch PDE Loss = 3.066590053389934e-05
#
# Batch Data Loss = 9.218271858365078e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 197                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000137
# Batch PDE Loss = 3.0268303715191897e-05
#
# Batch Data Loss = 9.206486475022596e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 198                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000135
# Batch PDE Loss = 3.008449800082986e-05
#
# Batch Data Loss = 8.979737673830752e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 199                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
#
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000134
# Batch PDE Loss = 2.9466442239390875e-05
#
# Batch Data Loss = 8.726423483039992e-06
#
# ------------------------------------------------------------------
#
# |                      Epoch 200                                  |
#
# ------------------------------------------------------------------
#
# | => | Batch 1 |
# | => | Batch 201 |
#
# | => | Batch 401 |
#
# | => | Batch 601 |
#
# ----------
#
# ++ Learning rate reduced, now at = 0.000133
# Batch PDE Loss = 2.9186568056477824e-05
#
# Batch Data Loss = 8.539351975959343e-06

# %%
# visualize losses
plt.figure(1, figsize=(16, 8));
plt.plot(np.log10(info["pde_loss"]), lw=2, color="red");
plt.title("PDE Loss vs. Epoch");

plt.figure(2, figsize=(16, 8));
plt.plot(np.log10(info["data_loss"]), lw=2, color="blue");
plt.title("Data Loss vs. Epoch");

# plt.figure(3, figsize=(16, 8));
# plt.plot(np.log10(info["reg_loss"]), lw=2, color="purple");
# plt.title("Regularity Loss vs. Epoch");
query = cartesian_data(pinn.tgrid, pinn.xgrid)

# D_pred = pinn.D_nn(query).reshape(pinn.nx, pinn.nt).T.detach().numpy()
# G_pred = pinn.G_nn(query).reshape(pinn.nx, pinn.nt).T.detach().numpy()
p_pred = pinn(query).reshape(pinn.nx, pinn.nt).T.detach().numpy()

# grids
tgrid = pinn.tgrid.detach().numpy()
xgrid = pinn.xgrid.detach().numpy()

p_exact = pinn.raw_data["pmc"]
dx = pinn.dx.item()
dt = pinn.dt.item()

# plt.figure(1);
# plt.contourf(xgrid, tgrid, G_pred);
# plt.colorbar();

# plt.figure(2);
# plt.plot(xgrid, G_pred[0:-1:10, :].T, alpha=0.4, lw=1.5);
# plt.plot(xgrid, 1.1*np.ones_like(xgrid), "--", lw=4.5, color="red", alpha=0.8, label="exact");
# plt.legend();

# %%
nx = 800
xgrid_fine = np.linspace(xmin, xmax, nx)
xgrid_fine = torch.tensor(xgrid_fine)
dx = xgrid_fine[1]-xgrid_fine[0]
nt = 1000
tgrid_fine = np.linspace(0., 5.0, nt)
tgrid_fine = torch.tensor(tgrid_fine)
dt = (tgrid_fine[1]-tgrid_fine[0]).item()

query_fine = cartesian_data(tgrid_fine, xgrid_fine)

G_pred_fine = pinn.G_nn(query_fine[:, 1][:, None]).reshape(nx, nt).T.detach().numpy()
p_pred_fine = pinn(query_fine).reshape(nx, nt).T.detach().numpy()

# %%
plt.figure(1);
plt.plot(xgrid_fine, G_pred_fine[0, :], color="red");
plt.plot(xgrid_fine, v(xgrid_fine), "--", color="blue", lw=5.0, alpha=.6, label="exact");
plt.legend(); 
plt.xlabel(r"$x$");
plt.ylabel(r"$G(x)$");

# %%
# interpolation
print(p_pred_fine.shape)
plt.contourf(xgrid_fine.detach().numpy(), tgrid_fine.detach().numpy(), p_pred_fine);
# Out:
# (1000, 800)

# %%
plt.contourf(pinn.xgrid.detach().numpy(), pinn.tgrid.detach().numpy(), pinn.raw_data["pmc"]);

# %%
dx = dx.item()

# %%
plt.figure(2);
# relative error in L^2 from KDE benchmark
l2_rel_err = np.sum(((p_pred-p_exact)**2)*dx, 1) / np.sum((p_exact**2)*dx, 1)
tgrid = pinn.tgrid.detach().numpy()
plt.plot(tgrid, l2_rel_err, color="red", lw=1.5);
plt.grid(True);
plt.title(r"Relative error in $L^2$");
plt.xlabel(r"$t$"); 
plt.ylabel(r"$L^2(\mathbb{R})$ error");

# %%
model_path = "./PINN/models/nonlinear_advection_epoch_200"
torch.save(pinn.state_dict(), model_path)

# %%
torch.load(model_path)
